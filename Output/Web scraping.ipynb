# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
argume=[('01-2009',36),('02-2009',33),('03-2009',36),('04-2009',35),('05-2009',36),('06-2009',35),('07-2009',36),('08-2009',36),('09-2009',35),('10-2009',36),('11-2009',35),('12-2009',36),('01-2010',36),('02-2010',33),('03-2010',36),('04-2010',35),('05-2010',36),('06-2010',35),('07-2010',36),('08-2010',36),('09-2010',35),('10-2010',36),('11-2010',35),('12-2010',36),('01-2011',36),('02-2011',33),('03-2011',36),('04-2011',35),('05-2011',36),('06-2011',35),('07-2011',36),('08-2011',36),('09-2011',35),('10-2011',36),('11-2011',35),('12-2011',36),('01-2012',36),('02-2012',34),('03-2012',36),('04-2012',35),('05-2012',36),('06-2012',35),('07-2012',36),('08-2012',36),('09-2012',35),('10-2012',36),('11-2012',35),('12-2012',36),('01-2013',36),('02-2013',33),('03-2013',36),('04-2013',35),('05-2013',36),('06-2013',35),('07-2013',36),('08-2013',36),('09-2011',35),('10-2013',36),('11-2013',35),('12-2013',36),('01-2014',36),('02-2014',33),('03-2014',36),('04-2014',35),('05-2014',36),('06-2014',35),('07-2014',36),('08-2014',36),('09-2014',35),('10-2014',36),('11-2014',35),('12-2014',36),('01-2015',36),('02-2015',33),('03-2015',36),('04-2015',35),('05-2015',36),('06-2015',35),('07-2015',36),('08-2015',36),('09-2015',35),('10-2015',36),('11-2015',35),('12-2015',36),('01-2016',36),('02-2016',34),('03-2016',36),('04-2016',35),('05-2016',36),('06-2016',35),('07-2016',36),('08-2016',36),('09-2016',35),('10-2016',36),('11-2016',35),('12-2016',36),('01-2017',36),('02-2017',33),('03-2017',36),('04-2017',35),('05-2017',36),('06-2017',35),('07-2017',36),('08-2017',36),('09-2017',35),('10-2017',36),('11-2017',35),('12-2017',36),('01-2018',36),('02-2018',33),('03-2018',36),('04-2018',35),('05-2018',36),('06-2018',35),('07-2018',36),('08-2018',36),('09-2018',35),('10-2018',36),('11-2018',35),('12-2018',36),('01-2019',36),('02-2019',33),('03-2019',36),('04-2019',35),('05-2019',36),('06-2019',35),('07-2019',36),('08-2019',36),('09-2019',35),('10-2019',36),('11-2019',35),('12-2019',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    years = requests.get(url)
    soup = BeautifulSoup(years.text, 'html.parser')
    TempMedias = []
    for tag in soup.select('tr'):
        TempMedias.append(tag)
    varia= TempMedias[b]
    return varia.select("td.tc2")[0].text
temps = {}
for e in argume:
    temps[e[0]] = funcioncita(e[0],e[1])
print(temps)
# Out:
# {('01-2009', 36): '4.1', ('02-2009', 33): '5.3', ('03-2009', 36): '8.5', ('04-2009', 35): '11.6', ('05-2009', 36): '14.2', ('06-2009', 35): '16.8', ('07-2009', 36): '18.1', ('08-2009', 36): '19.2', ('09-2009', 35): '16.3', ('10-2009', 36): '13.1', ('11-2009', 35): '10.6', ('12-2009', 36): '5.1', ('01-2010', 36): '2.5', ('02-2010', 33): '4.1', ('03-2010', 36): '7.2', ('04-2010', 35): '10.2', ('05-2010', 36): '12', ('06-
 36): '13', ('11-2018', 35): '10.6', ('12-2018', 36): '8.9', ('01-2019', 36): '5.8', ('02-2019', 33): '8.3', ('03-2019', 36): '10', ('04-2019', 35): '10.5', ('05-2019', 36): '13.9', ('06-2019', 35): '17.2', ('07-2019', 36): '20.5', ('08-2019', 36): '19.7', ('09-2019', 35): '16.7', ('10-2019', 36): '12.6', ('11-2019', 35): '8.3', ('12-2019', 36): '8.1'}

# %%
argume=[('01-2010',36),('02-2010',33),('03-2010',36),('04-2010',35),('05-2010',36),('06-2010',35),('07-2010',36),('08-2010',36),('09-2010',35),('10-2010',36),('11-2010',35),('12-2010',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2010 = requests.get(url)
    soup = BeautifulSoup(year2010.text, 'html.parser')
    TempMedia10 = []
    for tag in soup.select('tr'):
        TempMedia10.append(tag)
    varia= TempMedia10[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 2.5
# 4.1
# 7.2
# 10.2
# 12
# 17
# 19.9
# 17.2
# 15.1
# 11.8
# 7
# 1.8

# %%
argume=[('01-2011',36),('02-2011',33),('03-2011',36),('04-2011',35),('05-2011',36),('06-2011',35),('07-2011',36),('08-2011',36),('09-2011',35),('10-2011',36),('11-2011',35),('12-2011',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2011 = requests.get(url)
    soup = BeautifulSoup(year2011.text, 'html.parser')
    TempMedia11 = []
    for tag in soup.select('tr'):
        TempMedia11.append(tag)
    varia= TempMedia11[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 5.7
# 7.7
# 7.6
# 13.7
# 14.4
# 16.1
# 17
# 17.5
# 16.8
# 14.3
# 10.9
# 7.7

# %%
argume=[('01-2012',36),('02-2012',34),('03-2012',36),('04-2012',35),('05-2012',36),('06-2012',35),('07-2012',36),('08-2012',36),('09-2012',35),('10-2012',36),('11-2012',35),('12-2012',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2012 = requests.get(url)
    soup = BeautifulSoup(year2012.text, 'html.parser')
    TempMedia12 = []
    for tag in soup.select('tr'):
        TempMedia12.append(tag)
    varia= TempMedia12[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 7.1
# 5.1
# 9.2
# 8.9
# 13.7
# 15.3
# 17.2
# 18.8
# 15.2
# 11.2
# 8.1
# 6.2

# %%
argume=[('01-2013',36),('02-2013',33),('03-2013',36),('04-2013',35),('05-2013',36),('06-2013',35),('07-2013',36),('08-2013',36),('09-2011',35),('10-2013',36),('11-2013',35),('12-2013',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2013 = requests.get(url)
    soup = BeautifulSoup(year2013.text, 'html.parser')
    TempMedia13 = []
    for tag in soup.select('tr'):
        TempMedia13.append(tag)
    varia= TempMedia13[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 4.6
# 3.7
# 3.6
# 8.5
# 11.7
# 15.1
# 20.3
# 19.3
# 16.8
# 14.2
# 8.4
# 8.1

# %%
argume=[('01-2014',36),('02-2014',33),('03-2014',36),('04-2014',35),('05-2014',36),('06-2014',35),('07-2014',36),('08-2014',36),('09-2014',35),('10-2014',36),('11-2014',35),('12-2014',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2014 = requests.get(url)
    soup = BeautifulSoup(year2014.text, 'html.parser')
    TempMedia14 = []
    for tag in soup.select('tr'):
        TempMedia14.append(tag)
    varia= TempMedia14[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 7.8
# 8.2
# 9.5
# 12.3
# 14.3
# 17.5
# 20.1
# 17.6
# 17
# 14.7
# 10.4
# 7.2

# %%
argume=[('01-2015',36),('02-2015',33),('03-2015',36),('04-2015',35),('05-2015',36),('06-2015',35),('07-2015',36),('08-2015',36),('09-2015',35),('10-2015',36),('11-2015',35),('12-2015',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2015 = requests.get(url)
    soup = BeautifulSoup(year2015.text, 'html.parser')
    TempMedia15 = []
    for tag in soup.select('tr'):
        TempMedia15.append(tag)
    varia= TempMedia15[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 6.3
# 5.5
# 8.3
# 10.8
# 13.6
# 16.9
# 19.1
# 18.6
# 14.6
# 12.8
# 11.7
# 12.2

# %%
argume=[('01-2016',36),('02-2016',34),('03-2016',36),('04-2016',35),('05-2016',36),('06-2016',35),('07-2016',36),('08-2016',36),('09-2016',35),('10-2016',36),('11-2016',35),('12-2016',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2016 = requests.get(url)
    soup = BeautifulSoup(year2016.text, 'html.parser')
    TempMedia16 = []
    for tag in soup.select('tr'):
        TempMedia16.append(tag)
    varia= TempMedia16[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 7.3
# 6.8
# 7.4
# 9.5
# 14.3
# 16.5
# 19.5
# 19.8
# 18.7
# 12.6
# 8.1
# 8

# %%
argume=[('01-2017',36),('02-2017',33),('03-2017',36),('04-2017',35),('05-2017',36),('06-2017',35),('07-2017',36),('08-2017',36),('09-2017',35),('10-2017',36),('11-2017',35),('12-2017',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2017 = requests.get(url)
    soup = BeautifulSoup(year2017.text, 'html.parser')
    TempMedia17 = []
    for tag in soup.select('tr'):
        TempMedia17.append(tag)
    varia= TempMedia17[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 4.9
# 7.9
# 10.9
# 11.5
# 15.1
# 19.1
# 19.3
# 18.2
# 15.5
# 14.4
# 9
# 6.7

# %%
argume=[('01-2018',36),('02-2018',33),('03-2018',36),('04-2018',35),('05-2018',36),('06-2018',35),('07-2018',36),('08-2018',36),('09-2018',35),('10-2018',36),('11-2018',35),('12-2018',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2018 = requests.get(url)
    soup = BeautifulSoup(year2018.text, 'html.parser')
    TempMedia18 = []
    for tag in soup.select('tr'):
        TempMedia18.append(tag)
    varia= TempMedia18[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 7.5
# 4.4
# 6.7
# 12
# 15.4
# 18.2
# 22.2
# 19.6
# 16.1
# 13
# 10.6
# 8.9

# %%
argume=[('01-2019',36),('02-2019',33),('03-2019',36),('04-2019',35),('05-2019',36),('06-2019',35),('07-2019',36),('08-2019',36),('09-2019',35),('10-2019',36),('11-2019',35),('12-2019',36)]
def funcioncita(a,b):
    url = f'https://www.tutiempo.net/clima/{a}/ws-37683.html'
    year2019 = requests.get(url)
    soup = BeautifulSoup(year2019.text, 'html.parser')
    TempMedia19 = []
    for tag in soup.select('tr'):
        TempMedia19.append(tag)
    varia= TempMedia19[b]
    return varia.select("td.tc2")[0].text
for e in argume:
    print(funcioncita(e[0],e[1]))
# Out:
# 5.8
# 8.3
# 10
# 10.5
# 13.9
# 17.2
# 20.5
# 19.7
# 16.7
# 12.6
# 8.3
# 8.1
